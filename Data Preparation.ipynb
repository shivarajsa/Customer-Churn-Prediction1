# %% [markdown]
# ## Importing Required Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ## Importing Dataset

# %%
df = pd.read_excel("GL Assignment_Online Retail.xlsx", parse_dates=["InvoiceDate"])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    541909 non-null  object
#  1   StockCode    541909 non-null  object
#  2   Description  540455 non-null  object
#  3   Quantity     541909 non-null  int64
#  4   InvoiceDate  541909 non-null  datetime64[ns]
#  5   UnitPrice    541909 non-null  float64
#  6   CustomerID   406829 non-null  float64
#  7   Country      541909 non-null  object
# dtypes: datetime64[ns](1), float64(2), int64(1), object(4)
# memory usage: 33.1+ MB

# %%
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom
# 3 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom

# %%
print(df.shape)
# Out:
# (541909, 8)

# %%
df['Description'].nunique()
# Out:
# 4223

# %%
df['Country'].nunique()
# Out:
# 38

# %%
df['CustomerID'].nunique()
# Out:
# 4372

# %%
df['StockCode'].nunique()
# Out:
# 4070

# %%
df['InvoiceNo'].nunique()
# Out:
# 25900

# %% [markdown]
# #### Checking the null values

# %%
df.isna().sum()
# Out:
# InvoiceNo           0
# StockCode           0
# Description      1454
# Quantity            0
# InvoiceDate         0
# UnitPrice           0
# CustomerID     135080
# Country             0
# dtype: int64

# %%
df.describe().T
# Out:
#                count          mean          std       min       25%       50%  \
# Quantity    541909.0      9.552250   218.081158 -80995.00      1.00      3.00
# UnitPrice   541909.0      4.611114    96.759853 -11062.06      1.25      2.08
# CustomerID  406829.0  15287.690570  1713.600303  12346.00  13953.00  15152.00
#
#                  75%      max
# Quantity       10.00  80995.0
# UnitPrice       4.13  38970.0
# CustomerID  16791.00  18287.0

# %% [markdown]
# #### Grouping data by CustomerID to check number of rows

# %%
df.groupby('CustomerID').count()
# Out:
#             InvoiceNo  StockCode  Description  Quantity  InvoiceDate  \
# CustomerID
# 12346.0             2          2            2         2            2
# 12347.0           182        182          182       182          182
# 12348.0            31         31           31        31           31
# 12349.0            73         73           73        73           73
# 12350.0            17         17           17        17           17
# ...               ...        ...          ...       ...          ...
# 18280.0            10         10           10        10           10
# 18281.0             7          7            7         7            7
# 18282.0            13         13           13        13           13
# 18283.0           756        756          756       756          756
# 18287.0            70         70           70        70           70
#
#             UnitPrice  Country
# CustomerID
# 12346.0             2        2
# 12347.0           182      182
# 12348.0            31       31
# 12349.0            73       73
# 12350.0            17       17
# ...               ...      ...
# 18280.0            10       10
# 18281.0             7        7
# 18282.0            13       13
# 18283.0           756      756
# 18287.0            70       70
#
# [4372 rows x 7 columns]

# %% [markdown]
# #### Droping null values of CustomerID & Description as those are unique values

# %%
df.dropna(inplace = True)

# %%
df.isna().sum()
# Out:
# InvoiceNo      0
# StockCode      0
# Description    0
# Quantity       0
# InvoiceDate    0
# UnitPrice      0
# CustomerID     0
# Country        0
# dtype: int64

# %%
print(df.shape)
# Out:
# (406829, 8)

# %%
df.describe().T
# Out:
#                count          mean          std      min       25%       50%  \
# Quantity    406829.0     12.061303   248.693370 -80995.0      2.00      5.00
# UnitPrice   406829.0      3.460471    69.315162      0.0      1.25      1.95
# CustomerID  406829.0  15287.690570  1713.600303  12346.0  13953.00  15152.00
#
#                  75%      max
# Quantity       12.00  80995.0
# UnitPrice       3.75  38970.0
# CustomerID  16791.00  18287.0

# %%
dfNew = df.copy()

# %%
dfNew.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom
# 3 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom

# %% [markdown]
# #### Creating new columns by splitting Invoice date into Year, Month, Day & Day of Year

# %%
dfNew['Year'] = dfNew.InvoiceDate.dt.year

# %%
dfNew['Month'] = dfNew.InvoiceDate.dt.month

# %%
dfNew['Date'] = dfNew.InvoiceDate.dt.day

# %%
dfNew['Day of Year'] = dfNew.InvoiceDate.dt.dayofyear

# %%
dfNew.drop("InvoiceDate", axis = 1, inplace = True)

# %%
dfNew.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#    UnitPrice  CustomerID         Country  Year  Month  Date  Day of Year
# 0       2.55     17850.0  United Kingdom  2010     12     1          335
# 1       3.39     17850.0  United Kingdom  2010     12     1          335
# 2       2.75     17850.0  United Kingdom  2010     12     1          335
# 3       3.39     17850.0  United Kingdom  2010     12     1          335
# 4       3.39     17850.0  United Kingdom  2010     12     1          335

# %%
df['InvoiceDate']=df['InvoiceDate'].dt.date

# %%
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#   InvoiceDate  UnitPrice  CustomerID         Country
# 0  2010-12-01       2.55     17850.0  United Kingdom
# 1  2010-12-01       3.39     17850.0  United Kingdom
# 2  2010-12-01       2.75     17850.0  United Kingdom
# 3  2010-12-01       3.39     17850.0  United Kingdom
# 4  2010-12-01       3.39     17850.0  United Kingdom

# %%
df['InvoiceDate']=df['InvoiceDate'].astype(str)

# %%
df.drop(['InvoiceNo','StockCode','Description'],axis=1,inplace=True)

# %%
df[df['InvoiceDate'] <= '2011-08-31'].tail()
# Out:
#         Quantity InvoiceDate  UnitPrice  CustomerID         Country
# 320700        -3  2011-08-31       1.45     17451.0  United Kingdom
# 320701        -1  2011-08-31       3.95     17451.0  United Kingdom
# 320702        -1  2011-08-31       4.15     17451.0  United Kingdom
# 320703       -12  2011-08-31       1.45     17451.0  United Kingdom
# 320704        -1  2011-08-31      57.60     16422.0  United Kingdom

# %%
df.loc[:'2011-08-31'].tail()
# Out:
#         Quantity InvoiceDate  UnitPrice  CustomerID         Country
# 201095         1  2011-05-23       1.65     15311.0  United Kingdom
# 201096         1  2011-05-23       1.65     15311.0  United Kingdom
# 201097         1  2011-05-23       1.65     15311.0  United Kingdom
# 201098         1  2011-05-23       0.83     15311.0  United Kingdom
# 201099         1  2011-05-23       1.25     15311.0  United Kingdom

# %% [markdown]
# #### Spliting Data into two Dtasets as per the requirement.
# #### df1 = Transactions between 1st Dec 2010 to 31st Aug 2011
# #### df2 = Transactions between Sep 2011 to Dec 2011

# %%
df1 = df[df['InvoiceDate'] <= '2011-08-31']
df1
# Out:
#         Quantity InvoiceDate  UnitPrice  CustomerID         Country
# 0              6  2010-12-01       2.55     17850.0  United Kingdom
# 1              6  2010-12-01       3.39     17850.0  United Kingdom
# 2              8  2010-12-01       2.75     17850.0  United Kingdom
# 3              6  2010-12-01       3.39     17850.0  United Kingdom
# 4              6  2010-12-01       3.39     17850.0  United Kingdom
# ...          ...         ...        ...         ...             ...
# 320700        -3  2011-08-31       1.45     17451.0  United Kingdom
# 320701        -1  2011-08-31       3.95     17451.0  United Kingdom
# 320702        -1  2011-08-31       4.15     17451.0  United Kingdom
# 320703       -12  2011-08-31       1.45     17451.0  United Kingdom
# 320704        -1  2011-08-31      57.60     16422.0  United Kingdom
#
# [232053 rows x 5 columns]

# %% [markdown]
# #### df2 = Transactions between Sep 2011 to Dec 2011

# %%
df2 = df[df['InvoiceDate'] > '2011-08-31']
df2
# Out:
#         Quantity InvoiceDate  UnitPrice  CustomerID         Country
# 320705         8  2011-09-01       1.25     13509.0  United Kingdom
# 320706        24  2011-09-01       1.25     13509.0  United Kingdom
# 320708         2  2011-09-01      12.75     13305.0  United Kingdom
# 320709         8  2011-09-01       3.75     13305.0  United Kingdom
# 320710         4  2011-09-01       4.95     13305.0  United Kingdom
# ...          ...         ...        ...         ...             ...
# 541904        12  2011-12-09       0.85     12680.0          France
# 541905         6  2011-12-09       2.10     12680.0          France
# 541906         4  2011-12-09       4.15     12680.0          France
# 541907         4  2011-12-09       4.15     12680.0          France
# 541908         3  2011-12-09       4.95     12680.0          France
#
# [174776 rows x 5 columns]

# %% [markdown]
# #### Merging the Dataset on CustomerID

# %%
df3=pd.merge(df1,df2,on=['CustomerID'],how='inner')

# %%
df3.head()
# Out:
#    Quantity_x InvoiceDate_x  UnitPrice_x  CustomerID       Country_x  \
# 0          32    2010-12-01         1.69     13047.0  United Kingdom
# 1          32    2010-12-01         1.69     13047.0  United Kingdom
# 2          32    2010-12-01         1.69     13047.0  United Kingdom
# 3          32    2010-12-01         1.69     13047.0  United Kingdom
# 4          32    2010-12-01         1.69     13047.0  United Kingdom
#
#    Quantity_y InvoiceDate_y  UnitPrice_y       Country_y
# 0          10    2011-10-14         1.65  United Kingdom
# 1          10    2011-10-14         0.79  United Kingdom
# 2           6    2011-10-14         4.25  United Kingdom
# 3           8    2011-10-14         3.95  United Kingdom
# 4           6    2011-10-14         4.95  United Kingdom

# %% [markdown]
# #### Storing Repeated CustomerID in array(X)

# %%
X = df3['CustomerID'].unique()

# %%
X
# Out:
# array([13047., 12583., 13748., ..., 15690., 17777., 16278.])

# %%
len(X)
# Out:
# 1984

# %%
df4= df1.copy()
column= df4['CustomerID']

# %% [markdown]
# #### Creating Dataframe for CustomerID in array(X)

# %%
dff = pd.DataFrame(X)

# %%
dff
# Out:
#             0
# 0     13047.0
# 1     12583.0
# 2     13748.0
# 3     15291.0
# 4     14688.0
# ...       ...
# 1979  14660.0
# 1980  13726.0
# 1981  15690.0
# 1982  17777.0
# 1983  16278.0
#
# [1984 rows x 1 columns]

# %%
dff.insert( 0 , 'Churn', 'No')

dff
# Out:
#      Churn        0
# 0       No  13047.0
# 1       No  12583.0
# 2       No  13748.0
# 3       No  15291.0
# 4       No  14688.0
# ...    ...      ...
# 1979    No  14660.0
# 1980    No  13726.0
# 1981    No  15690.0
# 1982    No  17777.0
# 1983    No  16278.0
#
# [1984 rows x 2 columns]

# %%
dff
# Out:
#      Churn        0
# 0       No  13047.0
# 1       No  12583.0
# 2       No  13748.0
# 3       No  15291.0
# 4       No  14688.0
# ...    ...      ...
# 1979    No  14660.0
# 1980    No  13726.0
# 1981    No  15690.0
# 1982    No  17777.0
# 1983    No  16278.0
#
# [1984 rows x 2 columns]

# %% [markdown]
# #### data = Transactions between 1st Dec 2010 to 31st Aug 2011
#
# #### data1 = Creating Dataframe for CustomerID

# %%
data = df1.copy()

# %%
data
# Out:
#         Quantity InvoiceDate  UnitPrice  CustomerID         Country
# 0              6  2010-12-01       2.55     17850.0  United Kingdom
# 1              6  2010-12-01       3.39     17850.0  United Kingdom
# 2              8  2010-12-01       2.75     17850.0  United Kingdom
# 3              6  2010-12-01       3.39     17850.0  United Kingdom
# 4              6  2010-12-01       3.39     17850.0  United Kingdom
# ...          ...         ...        ...         ...             ...
# 320700        -3  2011-08-31       1.45     17451.0  United Kingdom
# 320701        -1  2011-08-31       3.95     17451.0  United Kingdom
# 320702        -1  2011-08-31       4.15     17451.0  United Kingdom
# 320703       -12  2011-08-31       1.45     17451.0  United Kingdom
# 320704        -1  2011-08-31      57.60     16422.0  United Kingdom
#
# [232053 rows x 5 columns]

# %% [markdown]
# #### data1 = Creating Dataframe for CustomerID

# %%
data1 = dff.copy()
data1
# Out:
#      Churn        0
# 0       No  13047.0
# 1       No  12583.0
# 2       No  13748.0
# 3       No  15291.0
# 4       No  14688.0
# ...    ...      ...
# 1979    No  14660.0
# 1980    No  13726.0
# 1981    No  15690.0
# 1982    No  17777.0
# 1983    No  16278.0
#
# [1984 rows x 2 columns]

# %%
data1.rename(columns = {'Churn':'Churn', 0 :'CustomerID'}, inplace = True)

# %%
data1
# Out:
#      Churn  CustomerID
# 0       No     13047.0
# 1       No     12583.0
# 2       No     13748.0
# 3       No     15291.0
# 4       No     14688.0
# ...    ...         ...
# 1979    No     14660.0
# 1980    No     13726.0
# 1981    No     15690.0
# 1982    No     17777.0
# 1983    No     16278.0
#
# [1984 rows x 2 columns]

# %% [markdown]
# #### Combining data & data1 to get Final data(data2) for Analysis

# %%
data2 = data1.combine_first(data)

# %%
data2
# Out:
#        Churn         Country  CustomerID InvoiceDate  Quantity  UnitPrice
# 0         No  United Kingdom     13047.0  2010-12-01       6.0       2.55
# 1         No  United Kingdom     12583.0  2010-12-01       6.0       3.39
# 2         No  United Kingdom     13748.0  2010-12-01       8.0       2.75
# 3         No  United Kingdom     15291.0  2010-12-01       6.0       3.39
# 4         No  United Kingdom     14688.0  2010-12-01       6.0       3.39
# ...      ...             ...         ...         ...       ...        ...
# 320700   NaN  United Kingdom     17451.0  2011-08-31      -3.0       1.45
# 320701   NaN  United Kingdom     17451.0  2011-08-31      -1.0       3.95
# 320702   NaN  United Kingdom     17451.0  2011-08-31      -1.0       4.15
# 320703   NaN  United Kingdom     17451.0  2011-08-31     -12.0       1.45
# 320704   NaN  United Kingdom     16422.0  2011-08-31      -1.0      57.60
#
# [232584 rows x 6 columns]

# %% [markdown]
# #### Labeling the NAN value as "YES"

# %%
data2["Churn"].fillna("Yes", inplace = True)

# %%
data2
# Out:
#        Churn         Country  CustomerID InvoiceDate  Quantity  UnitPrice
# 0         No  United Kingdom     13047.0  2010-12-01       6.0       2.55
# 1         No  United Kingdom     12583.0  2010-12-01       6.0       3.39
# 2         No  United Kingdom     13748.0  2010-12-01       8.0       2.75
# 3         No  United Kingdom     15291.0  2010-12-01       6.0       3.39
# 4         No  United Kingdom     14688.0  2010-12-01       6.0       3.39
# ...      ...             ...         ...         ...       ...        ...
# 320700   Yes  United Kingdom     17451.0  2011-08-31      -3.0       1.45
# 320701   Yes  United Kingdom     17451.0  2011-08-31      -1.0       3.95
# 320702   Yes  United Kingdom     17451.0  2011-08-31      -1.0       4.15
# 320703   Yes  United Kingdom     17451.0  2011-08-31     -12.0       1.45
# 320704   Yes  United Kingdom     16422.0  2011-08-31      -1.0      57.60
#
# [232584 rows x 6 columns]

# %% [markdown]
# #### Exporting the Final prepared dataset to csv format

# %%
data2.to_csv('Final Dataset for analysis.csv', index = False)
